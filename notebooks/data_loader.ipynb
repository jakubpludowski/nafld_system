# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset = pd.read_excel('../data/data.xlsx')
empty_data = dataset.dropna(how='all')
empty_data = empty_data.dropna(axis=1,how='all')
empty_data = empty_data.reset_index()
empty_data = empty_data.drop(columns=['L,p','index'])
dataset = empty_data

# %%
dataset = dataset.drop(columns=['ALT', 'AST', 'GGTP', 'wsp, Pr,',
       'INR', 'Erytrocyty', 'Hb', 'leukocyty', 'Płytki krwi'])

# %%
#Set equal label type for sick people
for i, row in dataset.iterrows():
    label = row['label']
    if label == ' s':
        dataset.at[i,'label'] = 's'
    elif label == 'S':
        dataset.at[i,'label'] = 's'

# %%
sick = dataset[(dataset['label']=='s')]
obese = dataset[(dataset['label']=='o')]
healthy = dataset[(dataset['label']=='k')]

# %%
def percent_missing(df):
    
    
    return percent_nan

def draw_missing(dataset):
    ifg = plt.figure(figsize=(9,4),dpi=150)
    percent_nan = percent_missing(dataset)
    sns.barplot(x=percent_nan.index,y=percent_nan)
    plt.xticks(rotation=90)
    plt.ylim(0,100)
    plt.ylabel("Percentage of missing data")
    plt.xlabel("Atribute")
    plt.title("Which atributes has missing data?")

draw_missing(dataset)

# %%
dataset.describe()
# Out:
#               age      weight      height         BMI      centyl  \
# count  229.000000  207.000000  208.000000  208.000000  127.000000
# mean    13.482455   66.596353    1.606257   25.198620   74.196850
# std      3.391279   22.361129    0.202655    5.494137   33.330962
# min      2.270000   14.500000    0.670000    7.653061    3.000000
# 25%     11.789041   54.250000    1.540000   21.122453   50.000000
# 50%     14.000000   67.000000    1.657500   25.126759   97.000000
# 75%     16.000000   81.000000    1.740000   28.648469   97.000000
# max     21.000000  127.300000    1.945000   40.429015   97.000000
#
#        mean_for_age  SD_populacji  Z_score_BMI  wątroba powiększona  \
# count    124.000000    123.000000   120.000000           275.000000
# mean      19.299194      2.701382     0.855838             0.040000
# std        1.769823      0.465180     3.836220             0.196316
# min       15.540000      1.280000   -10.881119             0.000000
# 25%       17.900000      2.520000    -0.433835             0.000000
# 50%       19.630000      2.710000     1.743748             0.000000
# 75%       20.790000      2.930000     2.603780             0.000000
# max       21.650000      3.300000    16.722513             1.000000
#
#        niejednorodnie podwyższona echogeniczność  ...         EPA    C22:2n-6  \
# count                                 275.000000  ...  275.000000  275.000000
# mean                                    0.058182  ...    0.364062    0.338989
# std                                     0.234514  ...    0.306308    0.116597
# min                                     0.000000  ...    0.050000    0.100000
# 25%                                     0.000000  ...    0.140000    0.250000
# 50%                                     0.000000  ...    0.190000    0.330000
# 75%                                     0.000000  ...    0.680000    0.405000
# max                                     1.000000  ...    1.100000    0.990000
#
#          C22:4n-6    C22:5n-6       C24:0    C24:1n-9    C22:5n-3         DHA  \
# count  275.000000  275.000000  275.000000  275.000000  275.000000  275.000000
# mean     0.355004    0.599156    0.221822    0.796567    0.721335    2.303855
# std      0.083025    0.268206    0.100396    0.283803    0.269221    0.514975
# min      0.100000    0.100000    0.100000    0.210000    0.320000    1.310000
# 25%      0.300000    0.375000    0.140000    0.610000    0.520000    2.010000
# 50%      0.360000    0.580000    0.190000    0.750000    0.680000    2.240000
# 75%      0.410000    0.855000    0.275000    0.930000    0.885000    2.580000
# max      0.570000    1.160000    0.500000    2.570000    1.710000    3.990000
#
#           AA/DGLA     DGLA/LA
# count  275.000000  275.000000
# mean     2.299476    0.158831
# std      0.777207    0.041243
# min      0.881664    0.069312
# 25%      1.682791    0.128310
# 50%      2.170543    0.152644
# 75%      2.871609    0.184758
# max      4.263959    0.282130
#
# [8 rows x 94 columns]

# %%
#For rows where there is no age or weight, put random age generated from normal distribution with mean age and standard deviation of age
np.random.seed(300464)
for set in [sick, obese, healthy]:
    mean_age = set[['age']].mean()
    std_age = set[['age']].std()
    for i, row in set.iterrows():
        (weight, age) = row[['weight','age']]
        if  pd.isnull(age):
            new_age = np.random.normal(mean_age,std_age)
            set.at[i,'age'] = new_age
        if (age < 5) and (weight > 40):
            new_age = np.random.normal(mean_age,std_age)
            set.at[i,'age'] = new_age

# %%
dataset = pd.concat((sick,healthy, obese))
dataset.describe()
# Out:
#               age      weight      height         BMI      centyl  \
# count  275.000000  207.000000  208.000000  208.000000  127.000000
# mean    13.615977   66.596353    1.606257   25.198620   74.196850
# std      3.113890   22.361129    0.202655    5.494137   33.330962
# min      2.270000   14.500000    0.670000    7.653061    3.000000
# 25%     11.816438   54.250000    1.540000   21.122453   50.000000
# 50%     14.000000   67.000000    1.657500   25.126759   97.000000
# 75%     16.000000   81.000000    1.740000   28.648469   97.000000
# max     21.000000  127.300000    1.945000   40.429015   97.000000
#
#        mean_for_age  SD_populacji  Z_score_BMI  wątroba powiększona  \
# count    124.000000    123.000000   120.000000           275.000000
# mean      19.299194      2.701382     0.855838             0.040000
# std        1.769823      0.465180     3.836220             0.196316
# min       15.540000      1.280000   -10.881119             0.000000
# 25%       17.900000      2.520000    -0.433835             0.000000
# 50%       19.630000      2.710000     1.743748             0.000000
# 75%       20.790000      2.930000     2.603780             0.000000
# max       21.650000      3.300000    16.722513             1.000000
#
#        niejednorodnie podwyższona echogeniczność  ...         EPA    C22:2n-6  \
# count                                 275.000000  ...  275.000000  275.000000
# mean                                    0.058182  ...    0.364062    0.338989
# std                                     0.234514  ...    0.306308    0.116597
# min                                     0.000000  ...    0.050000    0.100000
# 25%                                     0.000000  ...    0.140000    0.250000
# 50%                                     0.000000  ...    0.190000    0.330000
# 75%                                     0.000000  ...    0.680000    0.405000
# max                                     1.000000  ...    1.100000    0.990000
#
#          C22:4n-6    C22:5n-6       C24:0    C24:1n-9    C22:5n-3         DHA  \
# count  275.000000  275.000000  275.000000  275.000000  275.000000  275.000000
# mean     0.355004    0.599156    0.221822    0.796567    0.721335    2.303855
# std      0.083025    0.268206    0.100396    0.283803    0.269221    0.514975
# min      0.100000    0.100000    0.100000    0.210000    0.320000    1.310000
# 25%      0.300000    0.375000    0.140000    0.610000    0.520000    2.010000
# 50%      0.360000    0.580000    0.190000    0.750000    0.680000    2.240000
# 75%      0.410000    0.855000    0.275000    0.930000    0.885000    2.580000
# max      0.570000    1.160000    0.500000    2.570000    1.710000    3.990000
#
#           AA/DGLA     DGLA/LA
# count  275.000000  275.000000
# mean     2.299476    0.158831
# std      0.777207    0.041243
# min      0.881664    0.069312
# 25%      1.682791    0.128310
# 50%      2.170543    0.152644
# 75%      2.871609    0.184758
# max      4.263959    0.282130
#
# [8 rows x 94 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import RidgeCV
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %%
#####test

set = sick.copy()


set_to_predict = set[set['weight'].isnull()][['age', 'weight']].drop('weight', axis = 1)
set_train = set[set['weight'].notnull()][['age', 'weight']]

assert set.shape[0] == set_to_predict.shape[0] + set_train.shape[0]

X = set_train.drop('weight', axis = 1)
y = set_train['weight']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=515)

scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)
X_real = scaler.transform(set_to_predict)

alphas = np.arange(0.001,10,0.01)
ridge_cv_model = RidgeCV(alphas=alphas,scoring='neg_root_mean_squared_error',cv=4,fit_intercept=True)
ridge_cv_model.fit(X_train,y_train)


train_predictions = ridge_cv_model.predict(X_train)

var = mean_squared_error(y_train,train_predictions)



for i, row in set.iterrows():
        (weight, age) = row[['weight','age']]
        if  pd.isnull(weight):
            prediction = ridge_cv_model.predict(scaler.transform(np.reshape(a = np.array(age),newshape = (1,-1))))
            set.at[i,'weight'] = np.random.normal(prediction,var)
# Out:
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %% [markdown]
# # Weight

# %%
def predict_weight(set, loop=0, plots = False):
    set_to_predict = set[set['weight'].isnull()][['age', 'weight']].drop('weight', axis = 1)
    set_train = set[set['weight'].notnull()][['age', 'weight']]

    assert set.shape[0] == set_to_predict.shape[0] + set_train.shape[0]

    X = set_train.drop('weight', axis = 1)
    y = set_train['weight']

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=515)

    scaler = StandardScaler()
    scaler.fit(X_train)
    X_train = scaler.transform(X_train)
    X_test = scaler.transform(X_test)
    X_real = scaler.transform(set_to_predict)

    alphas = np.arange(0.001,10,0.01)
    ridge_cv_model = RidgeCV(alphas=alphas,scoring='neg_root_mean_squared_error',cv=4)
    ridge_cv_model.fit(X_train,y_train)

    test_predictions = ridge_cv_model.predict(X_test)

    MAE = mean_absolute_error(y_test,test_predictions)
    MSE = mean_squared_error(y_test,test_predictions)
    RMSE = np.sqrt(MSE)

    print(f'MAE: {MAE}\nRMSE: {RMSE}')

    real_predictions = ridge_cv_model.predict(X_real)

    set_to_predict = np.squeeze(set_to_predict)

    if plots:
        sns.scatterplot(x=set_to_predict, y=real_predictions)
        sns.scatterplot(data=set_train, x='age', y='weight')
        if loop == 0:
            plt.title('Sick')
        elif loop == 1:
            plt.title('Obese')
        elif loop == 2:
            plt.title('Healthy')
        plt.show()

    for i, row in set.iterrows():
        (weight, age) = row[['weight','age']]
        if  pd.isnull(weight):
            new_weight = ridge_cv_model.predict(scaler.transform(np.reshape(a = np.array(age),newshape = (1,-1))))

            set.at[i,'weight'] = new_weight

# %%
loop = 0 
for set in [sick, obese, healthy]:
    predict_weight(set, loop, True)
    loop +=1
# Out:
# MAE: 13.028519233008442
# RMSE: 16.233277347136415
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# MAE: 12.783036054044567
# RMSE: 16.953857988712933
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# MAE: 10.77500859047701
# RMSE: 11.623269469815153
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
sns.scatterplot(data=sick, x = 'age', y='weight', label= 'Sick')
sns.scatterplot(data=obese, x = 'age', y='weight', label = 'Obese' )
sns.scatterplot(data=healthy, x = 'age', y='weight', label = 'Healthy')
plt.xlabel('Age')
plt.ylabel('Weight')
plt.ylim((0,140))
plt.xlim((0,25))
plt.legend(loc=2)

# %%
dataset = pd.concat((sick,healthy, obese))
dataset.describe()
# Out:
#               age      weight      height         BMI      centyl  \
# count  275.000000  275.000000  208.000000  208.000000  127.000000
# mean    13.615977   66.448200    1.606257   25.198620   74.196850
# std      3.113890   20.236100    0.202655    5.494137   33.330962
# min      2.270000   14.500000    0.670000    7.653061    3.000000
# 25%     11.816438   55.450000    1.540000   21.122453   50.000000
# 50%     14.000000   65.103509    1.657500   25.126759   97.000000
# 75%     16.000000   80.000000    1.740000   28.648469   97.000000
# max     21.000000  127.300000    1.945000   40.429015   97.000000
#
#        mean_for_age  SD_populacji  Z_score_BMI  wątroba powiększona  \
# count    124.000000    123.000000   120.000000           275.000000
# mean      19.299194      2.701382     0.855838             0.040000
# std        1.769823      0.465180     3.836220             0.196316
# min       15.540000      1.280000   -10.881119             0.000000
# 25%       17.900000      2.520000    -0.433835             0.000000
# 50%       19.630000      2.710000     1.743748             0.000000
# 75%       20.790000      2.930000     2.603780             0.000000
# max       21.650000      3.300000    16.722513             1.000000
#
#        niejednorodnie podwyższona echogeniczność  ...         EPA    C22:2n-6  \
# count                                 275.000000  ...  275.000000  275.000000
# mean                                    0.058182  ...    0.364062    0.338989
# std                                     0.234514  ...    0.306308    0.116597
# min                                     0.000000  ...    0.050000    0.100000
# 25%                                     0.000000  ...    0.140000    0.250000
# 50%                                     0.000000  ...    0.190000    0.330000
# 75%                                     0.000000  ...    0.680000    0.405000
# max                                     1.000000  ...    1.100000    0.990000
#
#          C22:4n-6    C22:5n-6       C24:0    C24:1n-9    C22:5n-3         DHA  \
# count  275.000000  275.000000  275.000000  275.000000  275.000000  275.000000
# mean     0.355004    0.599156    0.221822    0.796567    0.721335    2.303855
# std      0.083025    0.268206    0.100396    0.283803    0.269221    0.514975
# min      0.100000    0.100000    0.100000    0.210000    0.320000    1.310000
# 25%      0.300000    0.375000    0.140000    0.610000    0.520000    2.010000
# 50%      0.360000    0.580000    0.190000    0.750000    0.680000    2.240000
# 75%      0.410000    0.855000    0.275000    0.930000    0.885000    2.580000
# max      0.570000    1.160000    0.500000    2.570000    1.710000    3.990000
#
#           AA/DGLA     DGLA/LA
# count  275.000000  275.000000
# mean     2.299476    0.158831
# std      0.777207    0.041243
# min      0.881664    0.069312
# 25%      1.682791    0.128310
# 50%      2.170543    0.152644
# 75%      2.871609    0.184758
# max      4.263959    0.282130
#
# [8 rows x 94 columns]

# %% [markdown]
# # Height

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import ElasticNetCV

# %%
def predict_height(set, loop, plots = False):
    
    set_to_predict = set[set['height'].isnull()][['age', 'weight', 'height']].drop('height', axis = 1)
    set_train = set[set['height'].notnull()][['age', 'weight', 'height']]

    assert set.shape[0] == set_to_predict.shape[0] + set_train.shape[0]
    
    X = set_train.drop(columns= 'height', axis = 1)
    y = set_train['height']
    polyniomial_transformer = PolynomialFeatures(degree=2, include_bias=False)
    polyniomial_transformer = polyniomial_transformer.fit(X)
    polynomial_features = polyniomial_transformer.transform(X)
    set_to_predict_poly = polyniomial_transformer.transform(set_to_predict)

    X_train, X_test, y_train, y_test = train_test_split(polynomial_features, y, test_size=0.1, random_state=515)

    scaler = StandardScaler()
    scaler.fit(X_train)
    X_train = scaler.transform(X_train)
    X_test = scaler.transform(X_test)
    X_real = scaler.transform(set_to_predict_poly)

    elasticnet = ElasticNetCV(l1_ratio=[.1, .5, .7,.9, .95, .99, 1],tol=0.01)
    elasticnet.fit(X_train, y_train)   

    
    test_predictions = elasticnet.predict(X_test)

    MAE = mean_absolute_error(y_test,test_predictions)
    MSE = mean_squared_error(y_test,test_predictions)
    RMSE = np.sqrt(MSE)

    print(f'MAE: {MAE}\nRMSE: {RMSE}')

    real_predictions = elasticnet.predict(X_real)

    set_to_predict = np.squeeze(set_to_predict[['age']])

    if plots:
        sns.scatterplot(x=set_to_predict, y=real_predictions)
        sns.scatterplot(data=set_train, x='age', y='height')
        if loop == 0:
            plt.title('Sick')
        elif loop == 1:
            plt.title('Obese')
        elif loop == 2:
            plt.title('Healthy')
        plt.show()

    for i, row in set.iterrows():
        if not(pd.notnull(row['height'])):
            row_data = np.expand_dims((row[['age', 'weight']].values), axis = 0 )
            
            row_data_poly = polyniomial_transformer.transform(row_data)
            new_height = elasticnet.predict(scaler.transform( row_data_poly))
            set.at[i,'height'] = new_height

# %%
loop = 0 
for set in [sick, obese, healthy]:
    predict_height(set, loop, True)
    loop +=1
# Out:
# MAE: 0.08151068803519815
# RMSE: 0.11065111766310169
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
# MAE: 0.06741008953747689
# RMSE: 0.07225008485784168
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
# MAE: 0.07401255022167508
# RMSE: 0.07593653592232645
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
# /home/vscode/.cache/pypoetry/virtualenvs/nafld-oOHi79fc-py3.9/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(

# %%
sns.scatterplot(data=sick, x = 'age', y='height', label= 'Sick')
sns.scatterplot(data=obese, x = 'age', y='height', label = 'Obese' )
sns.scatterplot(data=healthy, x = 'age', y='height', label = 'Healthy')
plt.xlabel('Age')
plt.ylabel('Height')
plt.ylim((0.8,2))
plt.xlim((0,25))
plt.legend(loc=2)

# %%
dataset = pd.concat((sick,healthy, obese))
dataset.describe()
# Out:
#               age      weight      height         BMI      centyl  \
# count  275.000000  275.000000  275.000000  208.000000  127.000000
# mean    13.615977   66.448200    1.616496   25.198620   74.196850
# std      3.113890   20.236100    0.184666    5.494137   33.330962
# min      2.270000   14.500000    0.670000    7.653061    3.000000
# 25%     11.816438   55.450000    1.550000   21.122453   50.000000
# 50%     14.000000   65.103509    1.660000   25.126759   97.000000
# 75%     16.000000   80.000000    1.740000   28.648469   97.000000
# max     21.000000  127.300000    1.945000   40.429015   97.000000
#
#        mean_for_age  SD_populacji  Z_score_BMI  wątroba powiększona  \
# count    124.000000    123.000000   120.000000           275.000000
# mean      19.299194      2.701382     0.855838             0.040000
# std        1.769823      0.465180     3.836220             0.196316
# min       15.540000      1.280000   -10.881119             0.000000
# 25%       17.900000      2.520000    -0.433835             0.000000
# 50%       19.630000      2.710000     1.743748             0.000000
# 75%       20.790000      2.930000     2.603780             0.000000
# max       21.650000      3.300000    16.722513             1.000000
#
#        niejednorodnie podwyższona echogeniczność  ...         EPA    C22:2n-6  \
# count                                 275.000000  ...  275.000000  275.000000
# mean                                    0.058182  ...    0.364062    0.338989
# std                                     0.234514  ...    0.306308    0.116597
# min                                     0.000000  ...    0.050000    0.100000
# 25%                                     0.000000  ...    0.140000    0.250000
# 50%                                     0.000000  ...    0.190000    0.330000
# 75%                                     0.000000  ...    0.680000    0.405000
# max                                     1.000000  ...    1.100000    0.990000
#
#          C22:4n-6    C22:5n-6       C24:0    C24:1n-9    C22:5n-3         DHA  \
# count  275.000000  275.000000  275.000000  275.000000  275.000000  275.000000
# mean     0.355004    0.599156    0.221822    0.796567    0.721335    2.303855
# std      0.083025    0.268206    0.100396    0.283803    0.269221    0.514975
# min      0.100000    0.100000    0.100000    0.210000    0.320000    1.310000
# 25%      0.300000    0.375000    0.140000    0.610000    0.520000    2.010000
# 50%      0.360000    0.580000    0.190000    0.750000    0.680000    2.240000
# 75%      0.410000    0.855000    0.275000    0.930000    0.885000    2.580000
# max      0.570000    1.160000    0.500000    2.570000    1.710000    3.990000
#
#           AA/DGLA     DGLA/LA
# count  275.000000  275.000000
# mean     2.299476    0.158831
# std      0.777207    0.041243
# min      0.881664    0.069312
# 25%      1.682791    0.128310
# 50%      2.170543    0.152644
# 75%      2.871609    0.184758
# max      4.263959    0.282130
#
# [8 rows x 94 columns]

# %%
draw_missing(dataset)

# %%
for column in ['insulina 0','HOMA IR','mean_for_age', 'SD_populacji','Z_score_BMI', 'GPx','GSH', 'ApoE', 'HDL','ApoA1','TCH','TG','LDL', 'ApoB', 'LCAT', 'VLDL', 'Lp(a)', 'TBARS']:
    dataset[column] = dataset[column].transform(lambda val: val.fillna(val.mean()))

# %%
dataset.loc[dataset['BMI'].isnull(), ['BMI']] = dataset[dataset['BMI'].isnull()]['weight']/(dataset[dataset['BMI'].isnull()]['height']**2)

# %% [markdown]
# ### Dealing with categorical columns

# %% [markdown]
# Change 'centyl' column

# %%
dataset[dataset['centyl'].notnull()]['centyl'] = dataset[dataset['centyl'].notnull()]['centyl'].apply(int)
for column in ['centyl']:
    dataset[column] = dataset[column].transform(lambda val: val.fillna(val.mean()))
# Out:
# /tmp/ipykernel_5525/1321646763.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset[dataset['centyl'].notnull()]['centyl'] = dataset[dataset['centyl'].notnull()]['centyl'].apply(int)

# %% [markdown]
# Change sex column to numerical

# %%
dataset.loc[dataset['sex'] != 'D', ['sex']] = 'C'
dataset['sex'] = pd.get_dummies(dataset['sex'],drop_first=True)

# %% [markdown]
# Change 'bilirubina' column

# %%
dataset.loc[dataset['bilirubina'] == '<1,0', ['bilirubina']] = 0.5
dataset.loc[dataset['bilirubina'] == '< 1,0', ['bilirubina']] = 0.5
dataset.loc[dataset['bilirubina'].isnull(), ['bilirubina']] = 1
dataset['bilirubina'] = dataset['bilirubina'].apply(float)

dataset.loc[dataset['bil. bezpośrednia '] == '<1,0', ['bil. bezpośrednia ']] = 0.5
dataset.loc[dataset['bil. bezpośrednia '] == '< 1,0', ['bil. bezpośrednia ']] = 0.5
dataset.loc[dataset['bil. bezpośrednia '].isnull(), ['bil. bezpośrednia ']] = 1
dataset['bil. bezpośrednia '] = dataset['bil. bezpośrednia '].apply(float)

# %% [markdown]
# Change 'visceral' column

# %%
dataset['visceral'] = dataset['visceral'].transform(lambda val: val.fillna(val.mean()))

# %% [markdown]
# ### Continue to fill missing values

# %%
draw_missing(dataset)

# %%
for column in ['beta-karoten','visceral.1','nadpowięziowy', 'podpowięziowy','wit, A', 'wit, E','proinsulina','Adiponectin','Leptin','Lep, Recep','Active IGF-1','Free IGF-1','Free BP-2','Free BP-3',]:
    dataset[column] = dataset[column].transform(lambda val: val.fillna(val.median()))

# %%
from sklearn.preprocessing import LabelBinarizer
lb = LabelBinarizer()
dataset['sex'] = lb.fit_transform(dataset['sex'])
def binarize(x, bin = False):
    if bin:
        if x == 's':
            return 0
        else:
            return 1
    else:
        if x == 's':
            return 0
        elif x == 'k':
            return 1
        elif x == 'o':
            return 2

# %% [markdown]
# DATA IS COMPLETE NOW

# %%
dataset
# Out:
#            age label  sex     weight    height        BMI    centyl  \
# 0    16.282192     s    0  94.500000  1.650000  34.710744  97.00000
# 1    13.432877     s    1  67.000000  1.600000  26.171875  96.00000
# 2    11.879452     s    1  70.000000  1.560000  28.763971  74.19685
# 3    10.904110     s    0  62.000000  1.450000  29.488704  74.19685
# 4    18.265753     s    1  79.500000  1.720000  26.872634  97.00000
# ..         ...   ...  ...        ...       ...        ...       ...
# 270  14.484484     o    1  81.851380  1.703677  28.200139  74.19685
# 271   2.270000     o    0  25.000000  0.980000  26.030820  74.19685
# 272  16.800000     o    1  90.000000  1.740000  29.900000  97.00000
# 273  18.163417     o    1  66.000000  1.650000  24.240000  74.19685
# 274  11.520000     o    0  71.978116  1.625585  27.238360  74.19685
#
#      mean_for_age  SD_populacji  Z_score_BMI  ...    EPA  C22:2n-6  C22:4n-6  \
# 0       20.790000      2.500000     5.568298  ...  0.567     0.112     0.196
# 1       19.100000      2.750000     2.571591  ...  0.390     0.250     0.280
# 2       19.299194      2.701382     0.855838  ...  0.950     0.330     0.510
# 3       19.299194      2.701382     0.855838  ...  0.270     0.240     0.470
# 4       21.640000      2.690000     1.945217  ...  0.910     0.190     0.300
# ..            ...           ...          ...  ...    ...       ...       ...
# 270     19.299194      2.701382     0.855838  ...  0.160     0.190     0.390
# 271     19.299194      2.701382     0.855838  ...  0.320     0.340     0.410
# 272     21.100000      2.520000     3.491308  ...  0.150     0.250     0.280
# 273     19.299194      2.701382     0.855838  ...  0.180     0.210     0.300
# 274     19.140000      3.090000     0.855838  ...  0.090     0.490     0.340
#
#      C22:5n-6  C24:0  C24:1n-9  C22:5n-3   DHA   AA/DGLA   DGLA/LA
# 0       0.158  0.151     0.436     1.547  1.68  0.881664  0.226844
# 1       0.150  0.130     0.670     1.310  2.52  3.193548  0.161374
# 2       0.130  0.210     0.600     1.710  1.85  2.092457  0.222764
# 3       0.410  0.250     0.430     1.610  2.23  1.568849  0.243139
# 4       0.250  0.470     1.050     1.410  2.98  1.467967  0.170871
# ..        ...    ...       ...       ...   ...       ...       ...
# 270     0.830  0.140     0.630     0.610  2.25  3.940678  0.131623
# 271     0.860  0.160     0.810     0.520  2.03  3.004695  0.107903
# 272     0.890  0.410     0.840     0.700  1.68  1.944444  0.154589
# 273     0.970  0.280     1.200     0.630  1.48  2.862745  0.155773
# 274     0.570  0.190     0.910     0.320  1.39  2.891566  0.119424
#
# [275 rows x 98 columns]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 275 entries, 0 to 274
# Data columns (total 98 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   age                                        275 non-null    float64
#  1   label                                      275 non-null    object
#  2   sex                                        275 non-null    int64
#  3   weight                                     275 non-null    float64
#  4   height                                     275 non-null    float64
#  5   BMI                                        275 non-null    float64
#  6   centyl                                     275 non-null    float64
#  7   mean_for_age                               275 non-null    float64
#  8   SD_populacji                               275 non-null    float64
#  9   Z_score_BMI                                275 non-null    float64
#  10  wątroba powiększona                        275 non-null    int64
#  11  niejednorodnie podwyższona echogeniczność  275 non-null    int64
#  12  zmiany ogniskowe                           275 non-null    int64
#  13  nadpowięziowy                              275 non-null    float64
#  14  podpowięziowy                              275 non-null    float64
#  15  visceral                                   275 non-null    float64
#  16  visceral.1                                 275 non-null    float64
#  17  bilirubina                                 275 non-null    float64
#  18  bil. bezpośrednia                          275 non-null    float64
#  19  wit, A                                     275 non-null    float64
#  20  wit, E                                     275 non-null    float64
#  21  beta-karoten                               275 non-null    float64
#  22  TBARS                                      275 non-null    float64
#  23  proinsulina                                275 non-null    float64
#  24  insulina 0                                 275 non-null    float64
#  25  glukoza 0                                  275 non-null    int64
#  26  HOMA IR                                    275 non-null    float64
#  27  TCH                                        275 non-null    float64
#  28  TG                                         275 non-null    float64
#  29  LCAT                                       275 non-null    float64
#  30  ApoA1                                      275 non-null    float64
#  31  ApoB                                       275 non-null    float64
#  32  ApoE                                       275 non-null    float64
#  33  Lp(a)                                      275 non-null    float64
#  34  LDL                                        275 non-null    float64
#  35  VLDL                                       275 non-null    float64
#  36  HDL                                        275 non-null    float64
#  37  GSH                                        275 non-null    float64
#  38  GPx                                        275 non-null    float64
#  39  Adiponectin                                275 non-null    float64
#  40  Leptin                                     275 non-null    float64
#  41  Lep, Recep                                 275 non-null    float64
#  42  Active IGF-1                               275 non-null    float64
#  43  Free IGF-1                                 275 non-null    float64
#  44  Free BP-2                                  275 non-null    float64
#  45  Free BP-3                                  275 non-null    float64
#  46  DHA/ARA                                    275 non-null    float64
#  47  C20:3n6/C18:3n6                            275 non-null    float64
#  48  C18:3n6/C18:2n6                            275 non-null    float64
#  49  MUFA                                       275 non-null    float64
#  50  SFA                                        275 non-null    float64
#  51  PUFA                                       275 non-null    float64
#  52  N3                                         275 non-null    float64
#  53  N6                                         275 non-null    float64
#  54  TRANS                                      275 non-null    float64
#  55  n3/n6                                      275 non-null    float64
#  56  C8:0                                       275 non-null    float64
#  57  C10:0                                      275 non-null    float64
#  58  C11:0                                      275 non-null    float64
#  59  C12:0                                      275 non-null    float64
#  60  C14:0                                      275 non-null    float64
#  61  C14:1 t                                    275 non-null    float64
#  62  C14:1                                      275 non-null    float64
#  63  C15:1                                      275 non-null    float64
#  64  C16:0                                      275 non-null    float64
#  65  C16:1 t                                    275 non-null    float64
#  66  C16:1n-7                                   275 non-null    float64
#  67  C17:0                                      275 non-null    float64
#  68  C17:1                                      275 non-null    float64
#  69  C18:0                                      275 non-null    float64
#  70  C18:1 t                                    275 non-null    float64
#  71  C18:1n-9                                   275 non-null    float64
#  72  C18:1n-7                                   275 non-null    float64
#  73  C18:2 tt                                   275 non-null    float64
#  74  LA                                         275 non-null    float64
#  75  GLA                                        275 non-null    float64
#  76  ALA                                        275 non-null    float64
#  77  C20:0                                      275 non-null    float64
#  78  C18:4n-3                                   275 non-null    float64
#  79  C20:1n-9                                   275 non-null    float64
#  80  C20:2n-6                                   275 non-null    float64
#  81  C20:3n-9                                   275 non-null    float64
#  82  DGLA                                       275 non-null    float64
#  83  AA                                         275 non-null    float64
#  84  C20:3n-3                                   275 non-null    float64
#  85  C22:0                                      275 non-null    float64
#  86  C22:1 t                                    275 non-null    float64
#  87  C22:1n-9                                   275 non-null    float64
#  88  EPA                                        275 non-null    float64
#  89  C22:2n-6                                   275 non-null    float64
#  90  C22:4n-6                                   275 non-null    float64
#  91  C22:5n-6                                   275 non-null    float64
#  92  C24:0                                      275 non-null    float64
#  93  C24:1n-9                                   275 non-null    float64
#  94  C22:5n-3                                   275 non-null    float64
#  95  DHA                                        275 non-null    float64
#  96  AA/DGLA                                    275 non-null    float64
#  97  DGLA/LA                                    275 non-null    float64
# dtypes: float64(92), int64(5), object(1)
# memory usage: 212.7+ KB

# %%
dataset_cat = dataset.copy()
dataset_bin = dataset.copy()
dataset_bin['label'] = dataset_bin['label'].apply(binarize, bin=True)
dataset_cat['label'] = dataset_cat['label'].apply(binarize)

# %%
dataset_cat.to_csv('../data/data_processed_cat.csv', index= False)
dataset_bin.to_csv('../data/data_processed_bin.csv', index= False)
dataset_bin.to_csv('../data/data_complete.csv', index= False)

# %%
data_check = pd.read_csv('../data/data_processed_bin.csv')
data_check.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 275 entries, 0 to 274
# Data columns (total 98 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   age                                        275 non-null    float64
#  1   label                                      275 non-null    int64
#  2   sex                                        275 non-null    int64
#  3   weight                                     275 non-null    float64
#  4   height                                     275 non-null    float64
#  5   BMI                                        275 non-null    float64
#  6   centyl                                     275 non-null    float64
#  7   mean_for_age                               275 non-null    float64
#  8   SD_populacji                               275 non-null    float64
#  9   Z_score_BMI                                275 non-null    float64
#  10  wątroba powiększona                        275 non-null    int64
#  11  niejednorodnie podwyższona echogeniczność  275 non-null    int64
#  12  zmiany ogniskowe                           275 non-null    int64
#  13  nadpowięziowy                              275 non-null    float64
#  14  podpowięziowy                              275 non-null    float64
#  15  visceral                                   275 non-null    float64
#  16  visceral.1                                 275 non-null    float64
#  17  bilirubina                                 275 non-null    float64
#  18  bil. bezpośrednia                          275 non-null    float64
#  19  wit, A                                     275 non-null    float64
#  20  wit, E                                     275 non-null    float64
#  21  beta-karoten                               275 non-null    float64
#  22  TBARS                                      275 non-null    float64
#  23  proinsulina                                275 non-null    float64
#  24  insulina 0                                 275 non-null    float64
#  25  glukoza 0                                  275 non-null    int64
#  26  HOMA IR                                    275 non-null    float64
#  27  TCH                                        275 non-null    float64
#  28  TG                                         275 non-null    float64
#  29  LCAT                                       275 non-null    float64
#  30  ApoA1                                      275 non-null    float64
#  31  ApoB                                       275 non-null    float64
#  32  ApoE                                       275 non-null    float64
#  33  Lp(a)                                      275 non-null    float64
#  34  LDL                                        275 non-null    float64
#  35  VLDL                                       275 non-null    float64
#  36  HDL                                        275 non-null    float64
#  37  GSH                                        275 non-null    float64
#  38  GPx                                        275 non-null    float64
#  39  Adiponectin                                275 non-null    float64
#  40  Leptin                                     275 non-null    float64
#  41  Lep, Recep                                 275 non-null    float64
#  42  Active IGF-1                               275 non-null    float64
#  43  Free IGF-1                                 275 non-null    float64
#  44  Free BP-2                                  275 non-null    float64
#  45  Free BP-3                                  275 non-null    float64
#  46  DHA/ARA                                    275 non-null    float64
#  47  C20:3n6/C18:3n6                            275 non-null    float64
#  48  C18:3n6/C18:2n6                            275 non-null    float64
#  49  MUFA                                       275 non-null    float64
#  50  SFA                                        275 non-null    float64
#  51  PUFA                                       275 non-null    float64
#  52  N3                                         275 non-null    float64
#  53  N6                                         275 non-null    float64
#  54  TRANS                                      275 non-null    float64
#  55  n3/n6                                      275 non-null    float64
#  56  C8:0                                       275 non-null    float64
#  57  C10:0                                      275 non-null    float64
#  58  C11:0                                      275 non-null    float64
#  59  C12:0                                      275 non-null    float64
#  60  C14:0                                      275 non-null    float64
#  61  C14:1 t                                    275 non-null    float64
#  62  C14:1                                      275 non-null    float64
#  63  C15:1                                      275 non-null    float64
#  64  C16:0                                      275 non-null    float64
#  65  C16:1 t                                    275 non-null    float64
#  66  C16:1n-7                                   275 non-null    float64
#  67  C17:0                                      275 non-null    float64
#  68  C17:1                                      275 non-null    float64
#  69  C18:0                                      275 non-null    float64
#  70  C18:1 t                                    275 non-null    float64
#  71  C18:1n-9                                   275 non-null    float64
#  72  C18:1n-7                                   275 non-null    float64
#  73  C18:2 tt                                   275 non-null    float64
#  74  LA                                         275 non-null    float64
#  75  GLA                                        275 non-null    float64
#  76  ALA                                        275 non-null    float64
#  77  C20:0                                      275 non-null    float64
#  78  C18:4n-3                                   275 non-null    float64
#  79  C20:1n-9                                   275 non-null    float64
#  80  C20:2n-6                                   275 non-null    float64
#  81  C20:3n-9                                   275 non-null    float64
#  82  DGLA                                       275 non-null    float64
#  83  AA                                         275 non-null    float64
#  84  C20:3n-3                                   275 non-null    float64
#  85  C22:0                                      275 non-null    float64
#  86  C22:1 t                                    275 non-null    float64
#  87  C22:1n-9                                   275 non-null    float64
#  88  EPA                                        275 non-null    float64
#  89  C22:2n-6                                   275 non-null    float64
#  90  C22:4n-6                                   275 non-null    float64
#  91  C22:5n-6                                   275 non-null    float64
#  92  C24:0                                      275 non-null    float64
#  93  C24:1n-9                                   275 non-null    float64
#  94  C22:5n-3                                   275 non-null    float64
#  95  DHA                                        275 non-null    float64
#  96  AA/DGLA                                    275 non-null    float64
#  97  DGLA/LA                                    275 non-null    float64
# dtypes: float64(92), int64(6)
# memory usage: 210.7 KB

# %%
sns.histplot(data=dataset_cat[dataset_cat['label'] == 0], x = "C12:0", bins=20)
plt.ylabel("Number of records")
plt.xlabel("Atribute value")
plt.xlim([0,2])
plt.ylim([0,45])
plt.title("Histogram of atribute C12:0 for sick patients")
# Out:
# Text(0.5, 1.0, 'Histogram of atribute C12:0 for sick patients')

# %%
sns.histplot(data=dataset_cat[dataset_cat['label'] == 1], x = "C12:0", bins=20)
plt.ylabel("Liczba rekordów")
plt.xlabel("Wartość atrybutu")
plt.xlim([0,2])
plt.ylim([0,45])
plt.title("Histogram atrybutu C12:0 - otyli")
# Out:
# Text(0.5, 1.0, 'Histogram atrybutu C12:0 - otyli')

# %%
sns.histplot(data=dataset_cat[dataset_cat['label'] == 2], x = "C12:0", bins=20)
plt.ylabel("Number of records")
plt.xlabel("Atribute value")
plt.xlim([0,2])
plt.ylim([0,45])
plt.title("Histogram of atribute C12:0 for healthy patients")
# Out:
# Text(0.5, 1.0, 'Histogram of atribute C12:0 for healthy patients')
